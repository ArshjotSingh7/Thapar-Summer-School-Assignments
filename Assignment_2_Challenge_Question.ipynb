# %% [markdown]
# <a href="https://colab.research.google.com/github/ArshjotSingh7/Thapar-Summer-School-Assignments/blob/main/Assignment_2_Challenge_Question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from types import LambdaType
L=["Ram",1,"Shyam",2,"Aman",3]
print(L)
newList = sorted(L, key = lambda x : (isinstance(x,int), x))
print(newList)
# Out:
# ['Ram', 1, 'Shyam', 2, 'Aman', 3]
# ['Aman', 'Ram', 'Shyam', 1, 2, 3]
